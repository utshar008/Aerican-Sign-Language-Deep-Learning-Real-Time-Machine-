# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
import os

# Set parameters
img_size = (64, 64)  # Resize all images to 64x64 pixels
batch_size = 32
epochs = 50

# Load dataset
data_dir = "Data"  # Path to dataset folder

# Prepare data generators
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,  # Normalize pixel values
    rotation_range=10,
    zoom_range=0.2,
    width_shift_range=0.1,
    height_shift_range=0.1,
    validation_split=0.2  # 20% of data for validation
)

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# Get the number of classes from the generator to dynamically adjust output shape
num_classes = train_generator.num_classes

# Model Architecture
model = Sequential([
    Input(shape=(img_size[0], img_size[1], 3)),  # Use Input layer to define the shape
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    GlobalAveragePooling2D(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')  # Output layer matches the number of classes dynamically
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=epochs
)

# Save the model
model.save("asl_model.keras")
print("Model training complete and saved as asl_model.h5")
# Out:
# Found 960 images belonging to 6 classes.
# Found 240 images belonging to 6 classes.
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 30s 894ms/step - accuracy: 0.1626 - loss: 1.7905 - val_accuracy: 0.1652 - val_loss: 1.7762
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.1875 - val_loss: 1.7769
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.2230 - loss: 1.7487 - val_accuracy: 0.3170 - val_loss: 1.5337
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.5625 - val_loss: 1.2752
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.4039 - loss: 1.3822 - val_accuracy: 0.5848 - val_loss: 0.9632
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.5625 - val_loss: 0.9081
# Epoch 7/50
# ...

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# Load the model
model = load_model("asl_model.keras")

# Load an image to predict
img_path = "Data/F/Image_1730917159.5490677.jpg"
img = image.load_img(img_path, target_size=img_size)
img_array = image.img_to_array(img) / 255.0  # Normalize image
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

# Predict the class
predictions = model.predict(img_array)
predicted_class = np.argmax(predictions)

# Map index to letter
class_labels = sorted(os.listdir(data_dir))  # Assumes folder names are alphabetically sorted
predicted_letter = class_labels[predicted_class]

print("Predicted Letter:", predicted_letter)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Predicted Letter: F
